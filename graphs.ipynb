# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
psnr_fista = np.load('metricas/Fista_psnr.npy')
psnr_ista = np.load('metricas/Ista_psnr.npy')

plt.figure(figsize=(10, 6)) 

# 3. Graficar el PSNR
plt.plot(psnr_fista, color='b', label='FISTA') 
plt.plot(psnr_ista, color='r', label='ISTA')

plt.title('Algorithms comparison: ratio 0.7 + Denoiser', fontsize=16)
plt.ylabel(r'PSNR (dB)', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.grid(True) 
plt.legend(fontsize=14)
plt.show()

# %%
error_fista = np.load('metricas/Fista_error.npy')
error_ista = np.load('metricas/Ista_error.npy')

plt.figure(figsize=(10, 6))
# 3. Graficar el error
plt.plot(error_fista, color='b', label='FISTA')
plt.plot(error_ista, color='r', label='ISTA')

plt.title('Algorithms comparison: ratio 0.7 + Denoiser', fontsize=16)
plt.yscale('log')
plt.ylabel(r'$\frac{1}{2} \|\mathbf{y} - \mathbf{H(x)}\|^2$', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
plt.show()

# %%
ratios = [0.3, 0.7]
colors = ['r', 'b']
plt.figure()
for idx, ratio in enumerate(ratios):
    convergence_fista = np.load(f'metricas/Fista_convergence_rate{ratio}.npy')
    psnr_final = np.load(f'metricas/Fista_psnr{ratio}.npy')
    psnr = psnr_final[:,0][-1]
    psnr = np.around(psnr, 4)
    print(psnr)
    plt.plot(convergence_fista[:,0], color=colors[idx], label=f'ratio {ratio}, psnr={psnr}')
#plt.yscale('log')
plt.ylabel(r'$\frac{\|\mathbf{x}^{l} - \mathbf{x}^{*}\|}{\|\mathbf{x}^{l-1} - \mathbf{x}^{*}\|} $', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('FISTA: Convergence rate', fontsize=16)
plt.show()
# Out:
# 25.4042
# 38.1524

# %%
convergence_fista = np.load(f'metricas/Fista_convergence_rate0.7.npy')
print(convergence_fista.shape)
convergence_fista[:,0].shape
# Out:
# (180, 128)
# (180,)

# %%
ratios = [0.3, 0.7]
colors = ['r', 'b']
plt.figure()
for idx, ratio in enumerate(ratios):
    change_vector_fista = np.load(f'metricas/Fista_change_vector{ratio}.npy')
    psnr_final = np.load(f'metricas/Fista_psnr{ratio}.npy')
    psnr = psnr_final[:,0][-1]
    psnr = np.around(psnr, 4)
    print(psnr)
    plt.plot(change_vector_fista[:,0], color=colors[idx], label=f'ratio {ratio}, psnr={psnr}')
#plt.yscale('log')
plt.ylabel(r'$\|\mathbf{x}^{l} - \mathbf{x}^{l-1}\| $', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('FISTA: Change Vector', fontsize=16)
plt.show()

# %%
psnr_final = np.load(f'metricas/Fista_psnr0.3.npy')
psnr_final.shape
# Out:
# (180,)

# %%
ratios = [0.3, 0.7]
colors = ['r', 'b']
plt.figure()
for idx, ratio in enumerate(ratios):
    convergence_fista = np.load(f'metricas/Ista_convergence_rate{ratio}.npy')
    psnr_final = np.load(f'metricas/Ista_psnr{ratio}.npy')[-1]
    plt.plot(convergence_fista, color=colors[idx], label=f'ratio {ratio}, psnr={np.around(psnr_final, 4)}')
# plt.yscale('log')
plt.ylabel(r'$\frac{\|\mathbf{x}^{l} - \mathbf{x}^{*}\|}{\|\mathbf{x}^{l-1} - \mathbf{x}^{*}\|} $', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('ISTA: Convergence rate', fontsize=16)
plt.show()

# %%
# LAISTA GRAPHS
convergence_laista = np.load('metricas/Laista_convergence_rate.npy')
change_laista = np.load('metricas/Laista_change_vector.npy')
error_laista = np.load('metricas/Laista_error.npy')
mse_laista = np.load('metricas/Laista_mse.npy')
psnr_laista = np.load('metricas/Laista_psnr.npy')

print(f'shape convergence rate: {convergence_laista.shape}, min = {convergence_laista.min()} in {np.argmin(convergence_laista)}, max = {convergence_laista.max()} in {np.argmax(convergence_laista)}')
print(f'shape change vector: {change_laista.shape}, min = {change_laista.min()} in {np.argmin(change_laista)}, max = {change_laista.max()} in {np.argmax(change_laista)}')
print(f'shape error: {error_laista.shape}, min = {error_laista.min()} in {np.argmin(error_laista)}, max = {error_laista.max()} in {np.argmax(error_laista)}')
print(f'shape mse: {mse_laista.shape}, min = {mse_laista.min()} in {np.argmin(mse_laista)}, max = {mse_laista.max()} in {np.argmax(mse_laista)}')
print(f'shape psnr: {psnr_laista.shape}, min = {psnr_laista.min()} in {np.argmin(psnr_laista)}, max = {psnr_laista.max()} in {np.argmax(psnr_laista)}')
# Out:
# shape convergence rate: (180, 128), min = 0.5109876394271851 in 693, max = 1.0024659633636475 in 17257
# shape change vector: (180, 128), min = 6.817271787440404e-05 in 23005, max = 11373.7841796875 in 72
# shape error: (180, 128), min = 2.6157126426696777 in 2457, max = 72428134400.0 in 72
# shape mse: (180, 128), min = 0.003953565843403339 in 22982, max = 0.0669713243842125 in 2013
# shape psnr: (180, 128), min = 11.741110801696777 in 2013, max = 24.030109405517578 in 22982

# %%
convergence_fista = np.load('metricas/Fista_convergence_rate0.7.npy')
convergence_ista = np.load('metricas/Ista_convergence_rate0.7.npy')
print(convergence_fista[:,0:1].shape)
print(convergence_ista[:,0:1].shape)
plt.figure()
plt.plot(convergence_laista[:,0:1], color='b', label=f'Laista')
plt.plot(convergence_fista[:,0:1], color='r', label=f'Fista')
plt.plot(convergence_ista[:,0:1], color='g', label=f'Ista')
# plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'$\frac{\|\mathbf{x}^{l} - \mathbf{x}^{*}\|}{\|\mathbf{x}^{l-1} - \mathbf{x}^{*}\|} $', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('Convergence rate - ratio = 0.7', fontsize=16)
plt.show()
# Out:
# (180, 1)
# (180, 1)

# %%
change_fista = np.load('metricas/Fista_change_vector0.7.npy')
change_ista = np.load('metricas/Ista_change_vector0.7.npy')
print(change_fista[:,0:1].shape)
print(change_ista[:,0:1].shape)
plt.figure()
plt.plot(change_laista[:,0:1], color='b', label=f'Laista')
plt.plot(change_fista[:,0:1], color='r', label=f'Fista')
plt.plot(change_ista[:,0:1], color='g', label=f'Ista')
plt.yscale('log')
plt.ylabel(r'$\|\mathbf{x}^{l} - \mathbf{x}^{l-1}\| $', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('Change Vector - ratio = 0.7', fontsize=16)
plt.show()
# Out:
# (180, 1)
# (180, 1)

# %%
psnr_fista = np.load('metricas/Fista_psnr0.7.npy')
psnr_ista = np.load('metricas/Ista_psnr0.7.npy')
print(psnr_fista.mean())
print(psnr_fista[:,0:1].shape)
print(psnr_ista[:,0:1].shape)
plt.figure()
plt.plot(psnr_laista[:,0:1], color='b', label=f'Laista')
plt.plot(psnr_fista[:,0:1], color='r', label=f'Fista')
plt.plot(psnr_ista[:,0:1], color='g', label=f'Ista')
plt.xscale('log')
plt.ylabel(r'$PSNR$', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('PSNR - ratio = 0.7', fontsize=16)
plt.show()
# Out:
# 28.332897
# (180, 1)
# (180, 1)

# %%
mse_fista = np.load('metricas/Fista_mse0.7.npy')
mse_ista = np.load('metricas/Ista_mse0.7.npy')
print(mse_fista[:,0:1].shape)
print(mse_ista[:,0:1].shape)
plt.figure()
plt.plot(mse_laista[:,0:1], color='b', label=f'Laista')
plt.plot(mse_fista[:,0:1], color='r', label=f'Fista')
plt.plot(mse_ista[:,0:1], color='g', label=f'Ista')
plt.yscale('log')
plt.xscale('log')
plt.ylabel(r'$MSE$', fontsize=14)
plt.xlabel(r'Iteration', fontsize=14)
plt.legend(fontsize=14)
plt.title('MSE - ratio = 0.7', fontsize=16)
plt.show()
# Out:
# (180, 1)
# (180, 1)
